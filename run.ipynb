# %%
from algorithms.td_daco import TD_DACO
from problemtd import ProblemTD

# %%
list = ['h100c101.csv', 'h100c102.csv', 'h100c103.csv', 'h100c104.csv', 'h100c105.csv', 'h100c106.csv', 'h100c107.csv', 'h100c108.csv', 'h100c109.csv', 'h100c201.csv', 'h100c202.csv', 'h100c203.csv', 'h100c204.csv', 'h100c205.csv', 'h100c206.csv', 'h100c207.csv', 'h100c208.csv', 'h100r101.csv', 'h100r102.csv', 'h100r103.csv', 'h100r104.csv', 'h100r105.csv', 'h100r106.csv', 'h100r107.csv', 'h100r108.csv', 'h100r109.csv', 'h100r110.csv', 'h100r111.csv', 'h100r112.csv', 'h100r201.csv', 'h100r202.csv', 'h100r203.csv', 'h100r204.csv', 'h100r205.csv', 'h100r206.csv', 'h100r207.csv', 'h100r208.csv', 'h100r209.csv', 'h100r210.csv', 'h100r211.csv', 'h100rc101.csv', 'h100rc102.csv', 'h100rc103.csv', 'h100rc104.csv', 'h100rc105.csv', 'h100rc106.csv', 'h100rc107.csv', 'h100rc108.csv', 'h100rc201.csv', 'h100rc202.csv', 'h100rc203.csv', 'h100rc204.csv', 'h100rc205.csv', 'h100rc206.csv', 'h100rc207.csv', 'h100rc208.csv']

# %%
import csv
import os

# Ensure the file is created and write the header
file_path = 'final_csv.csv'
if not os.path.exists(file_path):
    with open(file_path, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['key', 'td', 'rd'])  # Writing the header

result_csv = []
for i in list:
    problem1 = ProblemTD("/root/hungpd10/Query-Rewrite-KE-FPT/DVRPSD/data/dvrptw/100/" + i)
    haco = TD_DACO(problem1)
    result_csv.append(haco.result)
    
    # Write the result to the file immediately
    with open(file_path, mode='a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([i, haco.result[0], haco.result[1]])

print(result_csv)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 13
#      11 result_csv = []
#      12 for i in list:
# ---> 13     problem1 = ProblemTD("F:\\CodingEnvironment\\dvrpsd\\data\\dvrptw\\100\\" + i)
#      14     haco = TD_DACO(problem1)
#      15     result_csv.append(haco.result)
#
# File ~/hungpd10/Query-Rewrite-KE-FPT/DVRPSD/problemtd.py:15, in ProblemTD.__init__(self, instance)
#      12 request = []
#      13 # self.num_vehicle = 25
# ---> 15 df = pd.read_csv(instance)
#      16 customer_data = df.iloc[0:]
#      18 for num, row in customer_data.iterrows():
#
# ...

# %%
import csv
import os

# Ensure the file is created
file_path = 'final_csv.csv'
if not os.path.exists(file_path):
    with open(file_path, mode='w') as file:
        pass  # Just create the file

with open(file_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['key', 'td', 'rd'])  # Writing the header

    for idx, i in enumerate(list):
        writer.writerow([i, result_csv[idx][0], result_csv[idx][1]])

# %%
# Save result (plot result...)
