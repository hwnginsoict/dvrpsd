# %%
from problem import Problem
import numpy as np

# %%
np.random.seed(1)
problem = Problem("data/C200/C1_2_1.TXT")
network = problem.network
requests = problem.requests
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24636/2338076754.py in <module>
# ----> 1 np.random.seed(1)
#       2 problem = Problem("data/C200/C1_2_1.TXT")
#       3 network = problem.network
#       4 requests = problem.requests
#
# NameError: name 'np' is not defined

# %%
# Out:
# 79.25906888173743

# %%
# Define Problem

# Run RACO algorithm with above problem

# %%
# Save result (plot result...)
