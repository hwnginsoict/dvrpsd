# %%
from problem import Problem
from algorithms import raco
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 from problem import Problem
# ----> 2 from algorithms import raco
#
# File d:\HOCDIBANTRE\DVRPSD\algorithms\raco.py:1
# ----> 1 from .ant import *
#       2 from ..graph import Link, Node, Network
#       4 import copy, time
#
# File d:\HOCDIBANTRE\DVRPSD\algorithms\ant.py:1
# ----> 1 from ..graph import *
#       3 class Ant:
#       4     def __init__(self):
#
# ImportError: attempted relative import beyond top-level package

# %%
# Define Problem
problem1 = Problem("data/C200/C1_2_1.TXT")
# Run RACO algorithm with above problem

# %%
# Save result (plot result...)
